# %% [markdown]
# <a href="https://colab.research.google.com/github/youraveragefightingfrenchman/fa5programactivity/blob/main/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_total_price(price, quantity):
  total = price * quantity
  return total

price_per_item = float(input("Enter the price of one item: "))
quantity = int(input("Enter the number of items purchased: "))

total = calculate_total_price(price_per_item, quantity)

print(f"The total price is:{total}")
# Out:
# Enter the price of one item: 200
# Enter the number of items purchased: 10
# The total price is:2000.0
